# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#Import the datetime module from the datetime library
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#loop through all the cities in the list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Lot the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count
    record_count += 1
    
    #Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        #Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description})
    
    #If an error is experienced, skip the city
    except:
        print("City not found.  Skipping...")
        pass
    
#Indicate that Data Loading is complete
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found.  Skipping...
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | cortez
# Processing Record 6 of Set 1 | mulege
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | shingu
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found.  Skipping...
# Processing Record 11 of Set 1 | port elizabeth
# Processing Record 12 of Set 1 | orchard homes
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | isoka
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | erdemli
# Processing Record 17 of Set 1 | belushya guba
# City not found.  Skipping...
# Processing Record 18 of Set 1 | dubbo
# Processing Record 19 of Set 1 | launceston
# Processing Record 20 of Set 1 | ostrovnoy
# Processing Record 21 of Set 1 | santa eulalia del rio
# City not found.  Skipping...
# Processing Record 22 of Set 1 | havre-saint-pierre
# Processing Record 23 of Set 1 | naze
# Processing Record 24 of Set 1 | nalut
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | kayes
# Processing Record 27 of Set 1 | inirida
# Processing Record 28 of Set 1 | pedernales
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | grand river south east
# City not found.  Skipping...
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | mandurah
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | alofi
# Processing Record 37 of Set 1 | hovd
# Processing Record 38 of Set 1 | poya
# Processing Record 39 of Set 1 | morehead
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | arlit
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | lasa
# Processing Record 47 of Set 1 | hirara
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | dniprovka
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | monrovia
# Processing Record 2 of Set 2 | narsaq
# Processing Record 3 of Set 2 | asasa
# Processing Record 4 of Set 2 | pangnirtung
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 | qeshm
# Processing Record 7 of Set 2 | antofagasta
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | nezhinka
# Processing Record 10 of Set 2 | nizhniy baskunchak
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | ushtobe
# Processing Record 13 of Set 2 | qitaihe
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | penzance
# Processing Record 17 of Set 2 | grindavik
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | dennery
# Processing Record 20 of Set 2 | clyde
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | bafra
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | geraldton
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | chuy
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | hobyo
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | husavik
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | key largo
# Processing Record 35 of Set 2 | cockburn town
# Processing Record 36 of Set 2 | nizhneyansk
# City not found.  Skipping...
# Processing Record 37 of Set 2 | saleaula
# City not found.  Skipping...
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | tiksi
# Processing Record 40 of Set 2 | san roque
# Processing Record 41 of Set 2 | kargapolye
# City not found.  Skipping...
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | jensen beach
# Processing Record 44 of Set 2 | brae
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | olinda
# Processing Record 48 of Set 2 | naryan-mar
# Processing Record 49 of Set 2 | honiara
# Processing Record 50 of Set 2 | udachnyy
# Processing Record 1 of Set 3 | asau
# Processing Record 2 of Set 3 | scottsburgh
# City not found.  Skipping...
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | peace river
# Processing Record 6 of Set 3 | segesd
# Processing Record 7 of Set 3 | hithadhoo
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | louisbourg
# City not found.  Skipping...
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | sitka
# Processing Record 12 of Set 3 | shirakawa
# Processing Record 13 of Set 3 | hualmay
# Processing Record 14 of Set 3 | kutum
# Processing Record 15 of Set 3 | kiama
# Processing Record 16 of Set 3 | iquique
# Processing Record 17 of Set 3 | ahome
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | san isidro
# Processing Record 21 of Set 3 | goderich
# Processing Record 22 of Set 3 | eskasem
# City not found.  Skipping...
# Processing Record 23 of Set 3 | port hardy
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | campagna
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | laguna
# Processing Record 28 of Set 3 | asfi
# Processing Record 29 of Set 3 | bethel
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | aljezur
# Processing Record 32 of Set 3 | atoyac
# Processing Record 33 of Set 3 | sola
# Processing Record 34 of Set 3 | concarneau
# Processing Record 35 of Set 3 | sorland
# Processing Record 36 of Set 3 | hambantota
# Processing Record 37 of Set 3 | wagar
# Processing Record 38 of Set 3 | acapulco
# Processing Record 39 of Set 3 | yambio
# Processing Record 40 of Set 3 | igarka
# Processing Record 41 of Set 3 | ngunguru
# Processing Record 42 of Set 3 | aylmer
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found.  Skipping...
# Processing Record 44 of Set 3 | ilulissat
# Processing Record 45 of Set 3 | santa isabel
# Processing Record 46 of Set 3 | gizo
# Processing Record 47 of Set 3 | raudeberg
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | richards bay
# Processing Record 50 of Set 3 | georgetown
# Processing Record 1 of Set 4 | homer
# Processing Record 2 of Set 4 | saldanha
# Processing Record 3 of Set 4 | meyungs
# City not found.  Skipping...
# Processing Record 4 of Set 4 | tiarei
# Processing Record 5 of Set 4 | bulungu
# Processing Record 6 of Set 4 | barabai
# Processing Record 7 of Set 4 | deputatskiy
# Processing Record 8 of Set 4 | katsuura
# Processing Record 9 of Set 4 | atuona
# Processing Record 10 of Set 4 | talnakh
# Processing Record 11 of Set 4 | santa isabel do rio negro
# Processing Record 12 of Set 4 | mogadishu
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | kuldiga
# Processing Record 16 of Set 4 | umzimvubu
# City not found.  Skipping...
# Processing Record 17 of Set 4 | araouane
# Processing Record 18 of Set 4 | high level
# Processing Record 19 of Set 4 | tabou
# Processing Record 20 of Set 4 | killybegs
# Processing Record 21 of Set 4 | qaanaaq
# Processing Record 22 of Set 4 | wyndham
# Processing Record 23 of Set 4 | uyar
# Processing Record 24 of Set 4 | poum
# Processing Record 25 of Set 4 | ormara
# Processing Record 26 of Set 4 | formoso do araguaia
# City not found.  Skipping...
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | great falls
# Processing Record 30 of Set 4 | port perry
# Processing Record 31 of Set 4 | pontes e lacerda
# Processing Record 32 of Set 4 | saint george
# Processing Record 33 of Set 4 | dondo
# Processing Record 34 of Set 4 | nizwa
# Processing Record 35 of Set 4 | sampit
# Processing Record 36 of Set 4 | borba
# Processing Record 37 of Set 4 | sao filipe
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | tilichiki
# Processing Record 41 of Set 4 | krasnokamensk
# Processing Record 42 of Set 4 | agadez
# Processing Record 43 of Set 4 | freeport
# Processing Record 44 of Set 4 | baft
# Processing Record 45 of Set 4 | yar-sale
# Processing Record 46 of Set 4 | castro
# Processing Record 47 of Set 4 | asten
# Processing Record 48 of Set 4 | padang
# Processing Record 49 of Set 4 | anchorage
# Processing Record 50 of Set 4 | camacha
# Processing Record 1 of Set 5 | kaseda
# Processing Record 2 of Set 5 | dalvik
# Processing Record 3 of Set 5 | kahului
# Processing Record 4 of Set 5 | itanhaem
# Processing Record 5 of Set 5 | aswan
# Processing Record 6 of Set 5 | saint-joseph
# Processing Record 7 of Set 5 | maghama
# City not found.  Skipping...
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | okato
# Processing Record 10 of Set 5 | devonport
# Processing Record 11 of Set 5 | asyut
# Processing Record 12 of Set 5 | ribeira grande
# Processing Record 13 of Set 5 | vestmannaeyjar
# Processing Record 14 of Set 5 | te anau
# Processing Record 15 of Set 5 | alice springs
# Processing Record 16 of Set 5 | yirol
# City not found.  Skipping...
# Processing Record 17 of Set 5 | shellbrook
# Processing Record 18 of Set 5 | salalah
# Processing Record 19 of Set 5 | norman wells
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | north bend
# Processing Record 22 of Set 5 | barabinsk
# Processing Record 23 of Set 5 | mtambile
# Processing Record 24 of Set 5 | bengkulu
# Processing Record 25 of Set 5 | malwan
# City not found.  Skipping...
# Processing Record 26 of Set 5 | makeni
# Processing Record 27 of Set 5 | labrea
# Processing Record 28 of Set 5 | abhaynagar
# Processing Record 29 of Set 5 | nguiu
# City not found.  Skipping...
# Processing Record 30 of Set 5 | barentsburg
# City not found.  Skipping...
# Processing Record 31 of Set 5 | biak
# Processing Record 32 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 5 | baruun-urt
# Processing Record 34 of Set 5 | ulladulla
# Processing Record 35 of Set 5 | galesong
# Processing Record 36 of Set 5 | traralgon
# Processing Record 37 of Set 5 | maragheh
# Processing Record 38 of Set 5 | outjo
# Processing Record 39 of Set 5 | esso
# Processing Record 40 of Set 5 | mercedes
# Processing Record 41 of Set 5 | termiz
# Processing Record 42 of Set 5 | hamilton
# Processing Record 43 of Set 5 | paamiut
# Processing Record 44 of Set 5 | ventspils
# Processing Record 45 of Set 5 | toumodi
# Processing Record 46 of Set 5 | bodoco
# City not found.  Skipping...
# Processing Record 47 of Set 5 | kibala
# Processing Record 48 of Set 5 | muriti
# Processing Record 49 of Set 5 | meulaboh
# Processing Record 50 of Set 5 | kodiak
# Processing Record 1 of Set 6 | clyde river
# Processing Record 2 of Set 6 | chicama
# Processing Record 3 of Set 6 | katrineholm
# Processing Record 4 of Set 6 | kelso
# Processing Record 5 of Set 6 | boulder
# Processing Record 6 of Set 6 | dingle
# Processing Record 7 of Set 6 | mumford
# Processing Record 8 of Set 6 | bolungarvik
# City not found.  Skipping...
# Processing Record 9 of Set 6 | pauini
# Processing Record 10 of Set 6 | hasaki
# Processing Record 11 of Set 6 | nome
# Processing Record 12 of Set 6 | ulaangom
# Processing Record 13 of Set 6 | caucasia
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | vardo
# Processing Record 16 of Set 6 | kindu
# Processing Record 17 of Set 6 | saskylakh
# Processing Record 18 of Set 6 | san patricio
# Processing Record 19 of Set 6 | bani
# Processing Record 20 of Set 6 | nikitinskiy
# Processing Record 21 of Set 6 | the pas
# Processing Record 22 of Set 6 | puerto escondido
# Processing Record 23 of Set 6 | bom jardim
# Processing Record 24 of Set 6 | chunoyar
# Processing Record 25 of Set 6 | fortuna
# Processing Record 26 of Set 6 | leningradskiy
# Processing Record 27 of Set 6 | sabya
# Processing Record 28 of Set 6 | doha
# Processing Record 29 of Set 6 | ati
# Processing Record 30 of Set 6 | lolua
# City not found.  Skipping...
# Processing Record 31 of Set 6 | siyabuswa
# Processing Record 32 of Set 6 | zhigansk
# Processing Record 33 of Set 6 | acatlan
# Processing Record 34 of Set 6 | raga
# Processing Record 35 of Set 6 | ponta do sol
# Processing Record 36 of Set 6 | iqaluit
# Processing Record 37 of Set 6 | boqueirao
# Processing Record 38 of Set 6 | marcona
# City not found.  Skipping...
# Processing Record 39 of Set 6 | nijar
# Processing Record 40 of Set 6 | morant bay
# Processing Record 41 of Set 6 | samalaeulu
# City not found.  Skipping...
# Processing Record 42 of Set 6 | byron bay
# Processing Record 43 of Set 6 | sao felix do xingu
# Processing Record 44 of Set 6 | vao
# Processing Record 45 of Set 6 | batagay
# Processing Record 46 of Set 6 | guerrero negro
# Processing Record 47 of Set 6 | aklavik
# Processing Record 48 of Set 6 | opuwo
# Processing Record 49 of Set 6 | pankrushikha
# Processing Record 50 of Set 6 | khonuu
# City not found.  Skipping...
# Processing Record 1 of Set 7 | ozgon
# City not found.  Skipping...
# Processing Record 2 of Set 7 | tsihombe
# City not found.  Skipping...
# Processing Record 3 of Set 7 | umm durman
# City not found.  Skipping...
# Processing Record 4 of Set 7 | westport
# Processing Record 5 of Set 7 | metaxades
# Processing Record 6 of Set 7 | pimenta bueno
# Processing Record 7 of Set 7 | mantua
# Processing Record 8 of Set 7 | fort nelson
# Processing Record 9 of Set 7 | yulara
# Processing Record 10 of Set 7 | higuey
# City not found.  Skipping...
# Processing Record 11 of Set 7 | guara
# Processing Record 12 of Set 7 | tuatapere
# Processing Record 13 of Set 7 | mata
# Processing Record 14 of Set 7 | attawapiskat
# City not found.  Skipping...
# Processing Record 15 of Set 7 | guarapari
# Processing Record 16 of Set 7 | gaziantep
# Processing Record 17 of Set 7 | mrirt
# City not found.  Skipping...
# Processing Record 18 of Set 7 | almaznyy
# Processing Record 19 of Set 7 | carballo
# Processing Record 20 of Set 7 | opocno
# Processing Record 21 of Set 7 | shirokiy
# Processing Record 22 of Set 7 | zabaykalsk
# Processing Record 23 of Set 7 | samusu
# City not found.  Skipping...
# Processing Record 24 of Set 7 | sydney
# Processing Record 25 of Set 7 | campbellsville
# Processing Record 26 of Set 7 | samalkha
# Processing Record 27 of Set 7 | palabuhanratu
# City not found.  Skipping...
# Processing Record 28 of Set 7 | cabadiangan
# Processing Record 29 of Set 7 | turbat
# Processing Record 30 of Set 7 | bambanglipuro
# Processing Record 31 of Set 7 | aksu
# Processing Record 32 of Set 7 | hanzhong
# Processing Record 33 of Set 7 | muros
# Processing Record 34 of Set 7 | fukue
# Processing Record 35 of Set 7 | puerto madryn
# Processing Record 36 of Set 7 | ca mau
# Processing Record 37 of Set 7 | qaqortoq
# Processing Record 38 of Set 7 | conde
# Processing Record 39 of Set 7 | pathein
# Processing Record 40 of Set 7 | moron
# Processing Record 41 of Set 7 | srednekolymsk
# Processing Record 42 of Set 7 | mandalgovi
# Processing Record 43 of Set 7 | kinkala
# Processing Record 44 of Set 7 | diamantino
# Processing Record 45 of Set 7 | hohhot
# Processing Record 46 of Set 7 | sindor
# Processing Record 47 of Set 7 | dalbandin
# Processing Record 48 of Set 7 | manggar
# Processing Record 49 of Set 7 | san fernando
# Processing Record 50 of Set 7 | okhotsk
# Processing Record 1 of Set 8 | torbay
# Processing Record 2 of Set 8 | touros
# Processing Record 3 of Set 8 | amderma
# City not found.  Skipping...
# Processing Record 4 of Set 8 | college
# Processing Record 5 of Set 8 | kampene
# Processing Record 6 of Set 8 | yeppoon
# Processing Record 7 of Set 8 | xixiang
# Processing Record 8 of Set 8 | oranjestad
# Processing Record 9 of Set 8 | half moon bay
# Processing Record 10 of Set 8 | kovur
# Processing Record 11 of Set 8 | santa cruz
# Processing Record 12 of Set 8 | mae hong son
# Processing Record 13 of Set 8 | nemuro
# Processing Record 14 of Set 8 | miraflores
# Processing Record 15 of Set 8 | krasnyye baki
# Processing Record 16 of Set 8 | batemans bay
# Processing Record 17 of Set 8 | gurgan
# City not found.  Skipping...
# Processing Record 18 of Set 8 | ongandjera
# Processing Record 19 of Set 8 | velikie luki
# City not found.  Skipping...
# Processing Record 20 of Set 8 | phnum penh
# City not found.  Skipping...
# Processing Record 21 of Set 8 | kiboga
# Processing Record 22 of Set 8 | pacific grove
# Processing Record 23 of Set 8 | eregli
# Processing Record 24 of Set 8 | lamar
# Processing Record 25 of Set 8 | la rioja
# Processing Record 26 of Set 8 | shipitsyno
# Processing Record 27 of Set 8 | avera
# Processing Record 28 of Set 8 | kavaratti
# Processing Record 29 of Set 8 | san cristobal
# Processing Record 30 of Set 8 | ketchikan
# Processing Record 31 of Set 8 | eyl
# Processing Record 32 of Set 8 | itacare
# Processing Record 33 of Set 8 | orange cove
# Processing Record 34 of Set 8 | ahipara
# Processing Record 35 of Set 8 | ambikapur
# Processing Record 36 of Set 8 | kontagora
# Processing Record 37 of Set 8 | viedma
# Processing Record 38 of Set 8 | somerset
# Processing Record 39 of Set 8 | aksarka
# Processing Record 40 of Set 8 | colwyn bay
# Processing Record 41 of Set 8 | primorsk
# Processing Record 42 of Set 8 | margate
# Processing Record 43 of Set 8 | mirassol
# Processing Record 44 of Set 8 | sioux lookout
# Processing Record 45 of Set 8 | rio cuarto
# Processing Record 46 of Set 8 | roma
# Processing Record 47 of Set 8 | crab hill
# City not found.  Skipping...
# Processing Record 48 of Set 8 | kruisfontein
# Processing Record 49 of Set 8 | dudinka
# Processing Record 50 of Set 8 | sinnamary
# Processing Record 1 of Set 9 | mayo
# Processing Record 2 of Set 9 | sokolo
# Processing Record 3 of Set 9 | vanino
# Processing Record 4 of Set 9 | duz
# City not found.  Skipping...
# Processing Record 5 of Set 9 | sinazongwe
# Processing Record 6 of Set 9 | bacabal
# Processing Record 7 of Set 9 | korla
# Processing Record 8 of Set 9 | sharan
# Processing Record 9 of Set 9 | verkhnevilyuysk
# Processing Record 10 of Set 9 | tasiilaq
# Processing Record 11 of Set 9 | vila franca do campo
# Processing Record 12 of Set 9 | port-gentil
# Processing Record 13 of Set 9 | mbeya
# Processing Record 14 of Set 9 | rock springs
# Processing Record 15 of Set 9 | kadyy
# Processing Record 16 of Set 9 | bonfim
# Processing Record 17 of Set 9 | anloga
# Processing Record 18 of Set 9 | tocopilla
# Processing Record 19 of Set 9 | itarema
# Processing Record 20 of Set 9 | kinango
# Processing Record 21 of Set 9 | mnogovershinnyy
# Processing Record 22 of Set 9 | north myrtle beach
# Processing Record 23 of Set 9 | sivas
# Processing Record 24 of Set 9 | xuanhua
# Processing Record 25 of Set 9 | ippy
# Processing Record 26 of Set 9 | nishihara
# Processing Record 27 of Set 9 | ishigaki
# Processing Record 28 of Set 9 | vila velha
# Processing Record 29 of Set 9 | namibe
# Processing Record 30 of Set 9 | mys shmidta
# City not found.  Skipping...
# Processing Record 31 of Set 9 | knyaze-volkonskoye
# Processing Record 32 of Set 9 | beloha
# Processing Record 33 of Set 9 | carmo do paranaiba
# Processing Record 34 of Set 9 | sao joao da barra
# Processing Record 35 of Set 9 | port lincoln
# Processing Record 36 of Set 9 | lewiston
# Processing Record 37 of Set 9 | lata
# Processing Record 38 of Set 9 | elat
# Processing Record 39 of Set 9 | yakuplu
# Processing Record 40 of Set 9 | plettenberg bay
# Processing Record 41 of Set 9 | farah
# Processing Record 42 of Set 9 | challakere
# Processing Record 43 of Set 9 | inderborskiy
# City not found.  Skipping...
# Processing Record 44 of Set 9 | tumannyy
# City not found.  Skipping...
# Processing Record 45 of Set 9 | buraydah
# Processing Record 46 of Set 9 | cabra
# Processing Record 47 of Set 9 | salinopolis
# Processing Record 48 of Set 9 | marsh harbour
# Processing Record 49 of Set 9 | praia da vitoria
# Processing Record 50 of Set 9 | oistins
# Processing Record 1 of Set 10 | kamenka
# Processing Record 2 of Set 10 | wattegama
# Processing Record 3 of Set 10 | mangrol
# Processing Record 4 of Set 10 | kloulklubed
# Processing Record 5 of Set 10 | goshogawara
# Processing Record 6 of Set 10 | nelson bay
# Processing Record 7 of Set 10 | pisco
# Processing Record 8 of Set 10 | atar
# Processing Record 9 of Set 10 | luganville
# Processing Record 10 of Set 10 | cabedelo
# Processing Record 11 of Set 10 | takoradi
# Processing Record 12 of Set 10 | road town
# Processing Record 13 of Set 10 | fort abbas
# Processing Record 14 of Set 10 | uvinza
# Processing Record 15 of Set 10 | labuhan
# Processing Record 16 of Set 10 | port arthur
# Processing Record 17 of Set 10 | paungde
# Processing Record 18 of Set 10 | teguise
# Processing Record 19 of Set 10 | cayenne
# Processing Record 20 of Set 10 | mosquera
# Processing Record 21 of Set 10 | winchester
# Processing Record 22 of Set 10 | riyadh
# Processing Record 23 of Set 10 | codrington
# Processing Record 24 of Set 10 | dali
# Processing Record 25 of Set 10 | novo aripuana
# Processing Record 26 of Set 10 | cachoeiro de itapemirim
# Processing Record 27 of Set 10 | lunglei
# Processing Record 28 of Set 10 | dhone
# Processing Record 29 of Set 10 | kailua
# Processing Record 30 of Set 10 | sechura
# Processing Record 31 of Set 10 | lubango
# Processing Record 32 of Set 10 | saint-pierre
# Processing Record 33 of Set 10 | tabiauea
# City not found.  Skipping...
# Processing Record 34 of Set 10 | shihezi
# Processing Record 35 of Set 10 | mareeba
# Processing Record 36 of Set 10 | priiskovyy
# Processing Record 37 of Set 10 | ekimchan
# Processing Record 38 of Set 10 | baykit
# Processing Record 39 of Set 10 | broome
# Processing Record 40 of Set 10 | pendleton
# Processing Record 41 of Set 10 | kuche
# City not found.  Skipping...
# Processing Record 42 of Set 10 | mahibadhoo
# Processing Record 43 of Set 10 | abapo
# Processing Record 44 of Set 10 | miandoab
# Processing Record 45 of Set 10 | bathsheba
# Processing Record 46 of Set 10 | nong kung si
# Processing Record 47 of Set 10 | hay river
# Processing Record 48 of Set 10 | nur
# Processing Record 49 of Set 10 | wenling
# Processing Record 50 of Set 10 | esik
# Processing Record 1 of Set 11 | middlebury
# Processing Record 2 of Set 11 | zaranj
# Processing Record 3 of Set 11 | karratha
# Processing Record 4 of Set 11 | bichena
# Processing Record 5 of Set 11 | quatre cocos
# Processing Record 6 of Set 11 | port moresby
# Processing Record 7 of Set 11 | caravelas
# Processing Record 8 of Set 11 | dekoa
# City not found.  Skipping...
# Processing Record 9 of Set 11 | vanimo
# Processing Record 10 of Set 11 | filadelfia
# Processing Record 11 of Set 11 | marivan
# Processing Record 12 of Set 11 | huarmey
# Processing Record 13 of Set 11 | kesennuma
# City not found.  Skipping...
# Processing Record 14 of Set 11 | port hawkesbury
# Processing Record 15 of Set 11 | mill valley
# Processing Record 16 of Set 11 | syracuse
# Processing Record 17 of Set 11 | lipin bor
# Processing Record 18 of Set 11 | yellandu
# Processing Record 19 of Set 11 | egvekinot
# Processing Record 20 of Set 11 | pitimbu
# Processing Record 21 of Set 11 | hailey
# Processing Record 22 of Set 11 | bestobe
# Processing Record 23 of Set 11 | necochea
# Processing Record 24 of Set 11 | kropotkin
# Processing Record 25 of Set 11 | darlawn
# Processing Record 26 of Set 11 | tahe
# Processing Record 27 of Set 11 | rio gallegos
# Processing Record 28 of Set 11 | myaundzha
# Processing Record 29 of Set 11 | tarrafal
# Processing Record 30 of Set 11 | the valley
# Processing Record 31 of Set 11 | shimoda
# Processing Record 32 of Set 11 | englewood
# Processing Record 33 of Set 11 | okha
# Processing Record 34 of Set 11 | makakilo city
# Processing Record 35 of Set 11 | turukhansk
# Processing Record 36 of Set 11 | mezen
# Processing Record 37 of Set 11 | kasongo-lunda
# Processing Record 38 of Set 11 | rungata
# City not found.  Skipping...
# Processing Record 39 of Set 11 | bellavista
# Processing Record 40 of Set 11 | divnomorskoye
# Processing Record 41 of Set 11 | constitucion
# Processing Record 42 of Set 11 | klaksvik
# Processing Record 43 of Set 11 | ambilobe
# Processing Record 44 of Set 11 | alta floresta
# Processing Record 45 of Set 11 | vredendal
# Processing Record 46 of Set 11 | amarante do maranhao
# Processing Record 47 of Set 11 | akyab
# Processing Record 48 of Set 11 | erenhot
# Processing Record 49 of Set 11 | sonoita
# Processing Record 50 of Set 11 | makiyivka
# Processing Record 1 of Set 12 | dhekiajuli
# Processing Record 2 of Set 12 | porto novo
# Processing Record 3 of Set 12 | lorengau
# Processing Record 4 of Set 12 | koumra
# Processing Record 5 of Set 12 | matamoros
# Processing Record 6 of Set 12 | nosivka
# Processing Record 7 of Set 12 | vryburg
# Processing Record 8 of Set 12 | sedelnikovo
# City not found.  Skipping...
# Processing Record 9 of Set 12 | manali
# Processing Record 10 of Set 12 | lagoa
# Processing Record 11 of Set 12 | hami
# Processing Record 12 of Set 12 | semporna
# Processing Record 13 of Set 12 | da lat
# Processing Record 14 of Set 12 | burica
# City not found.  Skipping...
# Processing Record 15 of Set 12 | bogorodskoye
# Processing Record 16 of Set 12 | sumbe
# Processing Record 17 of Set 12 | agadir
# Processing Record 18 of Set 12 | haghartsin
# Processing Record 19 of Set 12 | winneba
# Processing Record 20 of Set 12 | iralaya
# Processing Record 21 of Set 12 | kirakira
# Processing Record 22 of Set 12 | astara
# Processing Record 23 of Set 12 | yingzhong
# City not found.  Skipping...
# Processing Record 24 of Set 12 | rasskazovo
# Processing Record 25 of Set 12 | kaeo
# Processing Record 26 of Set 12 | kamyaran
# Processing Record 27 of Set 12 | derzhavinsk
# Processing Record 28 of Set 12 | ejea de los caballeros
# Processing Record 29 of Set 12 | bosobolo
# Processing Record 30 of Set 12 | faya
# Processing Record 31 of Set 12 | ngukurr
# City not found.  Skipping...
# Processing Record 32 of Set 12 | yakeshi
# Processing Record 33 of Set 12 | neuquen
# Processing Record 34 of Set 12 | grumazesti
# Processing Record 35 of Set 12 | walla walla
# Processing Record 36 of Set 12 | namie
# Processing Record 37 of Set 12 | jizan
# Processing Record 38 of Set 12 | cabo rojo
# Processing Record 39 of Set 12 | toamasina
# Processing Record 40 of Set 12 | dokka
# Processing Record 41 of Set 12 | posse
# Processing Record 42 of Set 12 | tiznit
# Processing Record 43 of Set 12 | conceicao do araguaia
# Processing Record 44 of Set 12 | saint peter
# Processing Record 45 of Set 12 | tura
# Processing Record 46 of Set 12 | mishan
# Processing Record 47 of Set 12 | jati
# Processing Record 48 of Set 12 | zanjan
# Processing Record 49 of Set 12 | tori fatehpur
# Processing Record 50 of Set 12 | bubaque
# Processing Record 1 of Set 13 | waipawa
# Processing Record 2 of Set 13 | dukat
# Processing Record 3 of Set 13 | hofn
# Processing Record 4 of Set 13 | christchurch
# Processing Record 5 of Set 13 | sisimiut
# Processing Record 6 of Set 13 | orzhytsya
# Processing Record 7 of Set 13 | luena
# Processing Record 8 of Set 13 | burns lake
# Processing Record 9 of Set 13 | pozhva
# Processing Record 10 of Set 13 | jaciara
# Processing Record 11 of Set 13 | emilio carranza
# Processing Record 12 of Set 13 | abbeville
# Processing Record 13 of Set 13 | thinadhoo
# Processing Record 14 of Set 13 | yarmouth
# Processing Record 15 of Set 13 | olafsvik
# Processing Record 16 of Set 13 | jodhpur
# Processing Record 17 of Set 13 | khor
# Processing Record 18 of Set 13 | mugur-aksy
# Processing Record 19 of Set 13 | gaya
# Processing Record 20 of Set 13 | sabha
# Processing Record 21 of Set 13 | mananara
# Processing Record 22 of Set 13 | muzhi
# Processing Record 23 of Set 13 | petrozavodsk
# Processing Record 24 of Set 13 | port hedland
# Processing Record 25 of Set 13 | wulanhaote
# City not found.  Skipping...
# Processing Record 26 of Set 13 | luba
# Processing Record 27 of Set 13 | alanya
# Processing Record 28 of Set 13 | natal
# Processing Record 29 of Set 13 | koraput
# Processing Record 30 of Set 13 | mogochin
# City not found.  Skipping...
# Processing Record 31 of Set 13 | omsukchan
# Processing Record 32 of Set 13 | zabol
# Processing Record 33 of Set 13 | kholodnyy
# Processing Record 34 of Set 13 | leh
# Processing Record 35 of Set 13 | lazaro cardenas
# Processing Record 36 of Set 13 | malakal
# Processing Record 37 of Set 13 | sanchi
# Processing Record 38 of Set 13 | pyapon
# Processing Record 39 of Set 13 | victor harbor
# Processing Record 40 of Set 13 | waingapu
# Processing Record 41 of Set 13 | pimentel
# Processing Record 42 of Set 13 | obihiro
# Processing Record 43 of Set 13 | asayita
# City not found.  Skipping...
# Processing Record 44 of Set 13 | karauzyak
# City not found.  Skipping...
# Processing Record 45 of Set 13 | kisleta
# Processing Record 46 of Set 13 | ugoofaaru
# Processing Record 47 of Set 13 | hailin
# Processing Record 48 of Set 13 | inhambane
# Processing Record 49 of Set 13 | norrtalje
# Processing Record 50 of Set 13 | suez
# Processing Record 1 of Set 14 | thayetmyo
# Processing Record 2 of Set 14 | belmonte
# Processing Record 3 of Set 14 | jiuquan
# Processing Record 4 of Set 14 | bela
# Processing Record 5 of Set 14 | scarborough
# Processing Record 6 of Set 14 | ondorhaan
# City not found.  Skipping...
# Processing Record 7 of Set 14 | isangel
# Processing Record 8 of Set 14 | phangnga
# Processing Record 9 of Set 14 | talcahuano
# Processing Record 10 of Set 14 | los llanos de aridane
# Processing Record 11 of Set 14 | haines junction
# Processing Record 12 of Set 14 | zhangjiakou
# Processing Record 13 of Set 14 | rafai
# Processing Record 14 of Set 14 | cururupu
# Processing Record 15 of Set 14 | verkh-usugli
# Processing Record 16 of Set 14 | lugo
# Processing Record 17 of Set 14 | manokwari
# Processing Record 18 of Set 14 | verkhnyaya inta
# Processing Record 19 of Set 14 | puerto colombia
# Processing Record 20 of Set 14 | berdigestyakh
# Processing Record 21 of Set 14 | belousovka
# Processing Record 22 of Set 14 | banjarmasin
# Processing Record 23 of Set 14 | jiddah
# City not found.  Skipping...
# Processing Record 24 of Set 14 | kemin
# Processing Record 25 of Set 14 | manado
# Processing Record 26 of Set 14 | el alto
# Processing Record 27 of Set 14 | goure
# Processing Record 28 of Set 14 | puerto del rosario
# Processing Record 29 of Set 14 | jalu
# Processing Record 30 of Set 14 | deniliquin
# Processing Record 31 of Set 14 | junin
# Processing Record 32 of Set 14 | mweka
# Processing Record 33 of Set 14 | mehamn
# Processing Record 34 of Set 14 | dickinson
# Processing Record 35 of Set 14 | xiamen
# Processing Record 36 of Set 14 | san jeronimo
# Processing Record 37 of Set 14 | portland
# Processing Record 38 of Set 14 | chapada dos guimaraes
# Processing Record 39 of Set 14 | poronaysk
# Processing Record 40 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 41 of Set 14 | reconquista
# Processing Record 42 of Set 14 | san quintin
# Processing Record 43 of Set 14 | soyo
# Processing Record 44 of Set 14 | ossora
# Processing Record 45 of Set 14 | warqla
# City not found.  Skipping...
# Processing Record 46 of Set 14 | balykshi
# Processing Record 47 of Set 14 | coquimbo
# Processing Record 48 of Set 14 | severobaykalsk
# Processing Record 49 of Set 14 | vaitupu
# City not found.  Skipping...
# Processing Record 50 of Set 14 | linkoping
# Processing Record 1 of Set 15 | macaboboni
# City not found.  Skipping...
# Processing Record 2 of Set 15 | antalaha
# Processing Record 3 of Set 15 | henties bay
# Processing Record 4 of Set 15 | lethem
# Processing Record 5 of Set 15 | yerofey pavlovich
# Processing Record 6 of Set 15 | abu samrah
# Processing Record 7 of Set 15 | ures
# Processing Record 8 of Set 15 | upata
# Processing Record 9 of Set 15 | mahudha
# Processing Record 10 of Set 15 | puri
# Processing Record 11 of Set 15 | trojes
# Processing Record 12 of Set 15 | thakurgaon
# Processing Record 13 of Set 15 | mounana
# Processing Record 14 of Set 15 | tighnabruaich
# Processing Record 15 of Set 15 | redlands
# Processing Record 16 of Set 15 | kamaishi
# Processing Record 17 of Set 15 | chapais
# Processing Record 18 of Set 15 | zaysan
# Processing Record 19 of Set 15 | qui nhon
# Processing Record 20 of Set 15 | scottsbluff
# Processing Record 21 of Set 15 | college park
# Processing Record 22 of Set 15 | flagstaff
# Processing Record 23 of Set 15 | yuanping
# Processing Record 24 of Set 15 | fernan-nunez
# Processing Record 25 of Set 15 | alekseyevsk
# Processing Record 26 of Set 15 | swan hill
# Processing Record 27 of Set 15 | szczecinek
# Processing Record 28 of Set 15 | camana
# Processing Record 29 of Set 15 | novaya zaimka
# Processing Record 30 of Set 15 | sergeyevka
# Processing Record 31 of Set 15 | qostanay
# Processing Record 32 of Set 15 | rawson
# Processing Record 33 of Set 15 | odweyne
# Processing Record 34 of Set 15 | komsomolskiy
# Processing Record 35 of Set 15 | gushikawa
# Processing Record 36 of Set 15 | kelheim
# Processing Record 37 of Set 15 | trairi
# Processing Record 38 of Set 15 | tarakan
# Processing Record 39 of Set 15 | grand gaube
# Processing Record 40 of Set 15 | taltal
# Processing Record 41 of Set 15 | orlik
# Processing Record 42 of Set 15 | kizhinga
# Processing Record 43 of Set 15 | sirjan
# Processing Record 44 of Set 15 | zyryanka
# Processing Record 45 of Set 15 | asosa
# Processing Record 46 of Set 15 | kisangani
# Processing Record 47 of Set 15 | cascais
# Processing Record 48 of Set 15 | voloshka
# Processing Record 49 of Set 15 | bahia honda
# Processing Record 50 of Set 15 | high rock
# Processing Record 1 of Set 16 | jijiang
# Processing Record 2 of Set 16 | sur
# Processing Record 3 of Set 16 | tautira
# Processing Record 4 of Set 16 | voi
# Processing Record 5 of Set 16 | teberda
# Processing Record 6 of Set 16 | preobrazheniye
# Processing Record 7 of Set 16 | cedar city
# Processing Record 8 of Set 16 | vila
# Processing Record 9 of Set 16 | san andres
# Processing Record 10 of Set 16 | boa vista
# Processing Record 11 of Set 16 | grobina
# Processing Record 12 of Set 16 | esna
# Processing Record 13 of Set 16 | faro
# Processing Record 14 of Set 16 | staroaleyskoye
# Processing Record 15 of Set 16 | tari
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
#Convert the array of dictionaries to a Pandas dataframe
city_data_df = pd.DataFrame(city_data)

#Reorder the dataframe columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.65  115.33     89.55        23           0
# 1         Ushuaia      AR -54.80  -68.30     48.20        45          75
# 2           Bluff      NZ -46.60  168.33     57.99        91         100
# 3          Cortez      US  37.35 -108.59     33.80        55           1
# 4          Mulege      MX  26.88 -111.98     59.29        61          20
# 5      Chokurdakh      RU  70.63  147.92    -18.02        89          99
# 6          Shingu      JP  33.73  135.98     53.60        50          40
# 7           Airai      TL  -8.93  125.41     63.14       100         100
# 8  Port Elizabeth      ZA -33.92   25.57     71.60        88          75
# 9   Orchard Homes      US  46.86 -114.05     28.40        86          90
#
#    Wind Speed Current Description
# 0        7.85           clear sky
# 1       17.22       broken clouds
# 2       11.01     overcast clouds
# 3       10.29           clear sky
# 4        2.93          few clouds
# 5        7.83     overcast clouds
# 6       11.41    scattered clouds
# 7        2.71          light rain
# 8       17.22       broken clouds
# 9        3.36          light snow

# %%
#Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

#Export the city data into a csv
city_data_df.to_csv(output_data_file, index_label = "City_ID")
